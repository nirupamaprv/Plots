# %%
# %matplotlib inline 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


#Reading contents of Visitors.csv
visitors = pd.read_csv('Visitors.csv', index_col='Country')
#print(visitors)

#Create a histogram
#visitors.hist()

#Create a horizontal bar plot
#visitors.plot.barh(stacked=True)

#Create a vertical bar plot
visitors.plot.bar(stacked=True)
